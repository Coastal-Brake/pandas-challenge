# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head(20)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# ...

# %%
students_passing_math=(school_data_complete["math_score"] >= 70).sum()
students_passing_math
# Out:
# 29370

# %%
#huang_df = school_data_complete.groupby[["school_name"]=="Huang High School"]
#Huang = school_data_complete.groupby("school_name").get_group("Huang High School")
#P=Huang(["math_score"]>70).count.sum()
#Print(Huang["reading_score"].mean())

# %%
#students passing math
school_names = ["Huang High School", "Figueroa High School", "Shelton High School", "Hernandez High School",
                "Wilson High School", "Cabrera High School", "Bailey High School", "Holden High School",
                "Pena High School", "Wright High School", "Rodriguez High School", "Johnson High School",
                "Ford High School", "Thomas High School"]

# Create an empty list to store the number of students passing math for each school
school_students_pass_math = []

# Loop through each school and calculate the number of students passing math
for school_name in school_names:
    school_df = school_data_complete[school_data_complete["school_name"] == school_name]
    students_passing_math = (school_df["math_score"] >= 70).sum()
    school_students_pass_math.append(students_passing_math)

# Create a DataFrame to store the results
school_students_pass_math_data = {'Students Passing Math': school_students_pass_math}
per_school_pass_math = pd.DataFrame(school_students_pass_math_data, index=None)

# Print the result
print(per_school_pass_math)
# Out:
#     Students Passing Math
# 0                    1916
# 1                    1946
# 2                    1653
# 3                    3094
# 4                    2143
# 5                    1749
# 6                    3318
# 7                     395
# 8                     910
# 9                    1680
# 10                   2654
# 11                   3145
# 12                   1871
# 13                   1525

# %%
school_list="none"
#[
#"Huang High School",
#"Figueroa High School",
#"Shelton High School",
#"Hernandez High School",
#"Griffin High School",
#"Wilson High School",
#"Cabrera High School",
#"Bailey High School",
#"Holden High School",
#"Pena High School",
#"Wright High School",
#"Rodriguez High School",
#"Johnson High School",
#"Ford High School",
#"Thomas High School"
#]
#print(school_list)

# %%
Huang_hs_df = school_data_complete[school_data_complete["school_name"] == "Huang High School"]
Figueroa_hs_df = school_data_complete[school_data_complete["school_name"] == "Figueroa High School"]
Shelton_hs_df = school_data_complete[school_data_complete["school_name"] == "Shelton High School"]
Hernandez_hs_df = school_data_complete[school_data_complete["school_name"] == "Hernandez High School"]
Griffin_hs_df = school_data_complete[school_data_complete["school_name"] == "Griffin High School"]
Wilson_hs_df = school_data_complete[school_data_complete["school_name"] == "Wilson High School"]
Cabrera_hs_df = school_data_complete[school_data_complete["school_name"] == "Cabrera High School"]
Bailey_hs_df = school_data_complete[school_data_complete["school_name"] == "Bailey High School"]
Holden_hs_df = school_data_complete[school_data_complete["school_name"] == "Holden High School"]
Pena_hs_df = school_data_complete[school_data_complete["school_name"] == "Pena High School"]
Wright_hs_df = school_data_complete[school_data_complete["school_name"] == "Wright High School"]
Rodriguez_hs_df = school_data_complete[school_data_complete["school_name"] == "Rodriguez High School"]
Johnson_hs_df = school_data_complete[school_data_complete["school_name"] == "Johnson High School"]
Ford_hs_df = school_data_complete[school_data_complete["school_name"] == "Ford High School"]
Thomas_hs_df = school_data_complete[school_data_complete["school_name"] == "Thomas High School"]

# %%
school_students_pass_math=[]
school_students_pass_math.append((Huang_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Figueroa_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Shelton_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Hernandez_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Wilson_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Cabrera_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Bailey_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Holden_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Pena_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Wright_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Rodriguez_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Johnson_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Ford_hs_df["math_score"] >= 70).sum())
school_students_pass_math.append((Thomas_hs_df["math_score"] >= 70).sum())
print(count_passing_math)

school_students_pass_math_data = {'Students Passing Math': school_students_pass_math}
per_school_pass_math = pd.DataFrame(school_students_pass_math_data, index=None)

per_school_pass_math
# Out:
# [1916, 1946, 1653, 3094, 2143, 1749, 3318, 395, 910, 1680, 2654, 3145, 1871, 1525]
#     Students Passing Math
# 0                    1916
# 1                    1946
# 2                    1653
# 3                    3094
# 4                    2143
# 5                    1749
# 6                    3318
# 7                     395
# 8                     910
# 9                    1680
# 10                   2654
# 11                   3145
# 12                   1871
# 13                   1525

# %%
student_count=[]
student_count.append(Huang_hs_df["student_name"].count())
student_count.append(Figueroa_hs_df["student_name"].count())
student_count.append(Shelton_hs_df["student_name"].count())
student_count.append(Hernandez_hs_df["student_name"].count())
student_count.append(Griffin_hs_df["student_name"].count())
student_count.append(Wilson_hs_df["student_name"].count())
student_count.append(Cabrera_hs_df["student_name"].count())
student_count.append(Bailey_hs_df["student_name"].count())
student_count.append(Holden_hs_df["student_name"].count())
student_count.append(Pena_hs_df["student_name"].count())
student_count.append(Wright_hs_df["student_name"].count())
student_count.append(Rodriguez_hs_df["student_name"].count())
student_count.append(Johnson_hs_df["student_name"].count())
student_count.append(Ford_hs_df["student_name"].count())
student_count.append(Thomas_hs_df["student_name"].count())

student_count_data = {'Student Count Per School': student_count}

per_school_student_count = pd.DataFrame(student_count_data, index=None)

per_school_student_count.head(15)
# Out:
#     Student Count Per School
# 0                       2917
# 1                       2949
# 2                       1761
# 3                       4635
# 4                       1468
# 5                       2283
# 6                       1858
# 7                       4976
# 8                        427
# 9                        962
# 10                      1800
# 11                      3999
# 12                      4761
# 13                      2739
# 14                      1635

# %%
math_score_avg=[]
math_score_avg.append(Huang_hs_df["math_score"].mean())
math_score_avg.append(Figueroa_hs_df["math_score"].mean())
math_score_avg.append(Shelton_hs_df["math_score"].mean())
math_score_avg.append(Hernandez_hs_df["math_score"].mean())
math_score_avg.append(Griffin_hs_df["math_score"].mean())
math_score_avg.append(Wilson_hs_df["math_score"].mean())
math_score_avg.append(Cabrera_hs_df["math_score"].mean())
math_score_avg.append(Bailey_hs_df["math_score"].mean())
math_score_avg.append(Holden_hs_df["math_score"].mean())
math_score_avg.append(Pena_hs_df["math_score"].mean())
math_score_avg.append(Wright_hs_df["math_score"].mean())
math_score_avg.append(Rodriguez_hs_df["math_score"].mean())
math_score_avg.append(Johnson_hs_df["math_score"].mean())
math_score_avg.append(Ford_hs_df["math_score"].mean())
math_score_avg.append(Thomas_hs_df["math_score"].mean())

math_score_avg_data = {'Math Score Avg Per School': math_score_avg}
per_school_math = pd.DataFrame(math_score_avg_data, index=None)

per_school_math.head(15)
# Out:
#     Math Score Avg Per School
# 0                   76.629414
# 1                   76.711767
# 2                   83.359455
# 3                   77.289752
# 4                   83.351499
# 5                   83.274201
# 6                   83.061895
# 7                   77.048432
# 8                   83.803279
# 9                   83.839917
# 10                  83.682222
# 11                  76.842711
# 12                  77.072464
# 13                  77.102592
# 14                  83.418349

# %%
reading_score_avg=[]
reading_score_avg.append(Huang_hs_df["reading_score"].mean())
reading_score_avg.append(Figueroa_hs_df["reading_score"].mean())
reading_score_avg.append(Shelton_hs_df["reading_score"].mean())
reading_score_avg.append(Hernandez_hs_df["reading_score"].mean())
reading_score_avg.append(Griffin_hs_df["reading_score"].mean())
reading_score_avg.append(Wilson_hs_df["reading_score"].mean())
reading_score_avg.append(Cabrera_hs_df["reading_score"].mean())
reading_score_avg.append(Bailey_hs_df["reading_score"].mean())
reading_score_avg.append(Holden_hs_df["reading_score"].mean())
reading_score_avg.append(Pena_hs_df["reading_score"].mean())
reading_score_avg.append(Wright_hs_df["reading_score"].mean())
reading_score_avg.append(Rodriguez_hs_df["reading_score"].mean())
reading_score_avg.append(Johnson_hs_df["reading_score"].mean())
reading_score_avg.append(Ford_hs_df["reading_score"].mean())
reading_score_avg.append(Thomas_hs_df["reading_score"].mean())

reading_score_avg_data = {'Reading Score Avg Per School': reading_score_avg}
per_school_reading = pd.DataFrame(reading_score_avg_data, index=None)


per_school_reading.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     Reading Score Avg Per School
# 0                      81.182722
# 1                      81.158020
# 2                      83.725724
# 3                      80.934412
# 4                      83.816757
# 5                      83.989488
# 6                      83.975780
# 7                      81.033963
# 8                      83.814988
# 9                      84.044699
# 10                     83.955000
# 11                     80.744686
# 12                     80.966394
# 13                     80.746258
# 14                     83.848930>

# %%
budget=school_data.iloc[:,4]
# Out:
# 0     1910635
# 1     1884411
# 2     1056600
# 3     3022020
# 4      917500
# 5     1319574
# 6     1081356
# 7     3124928
# 8      248087
# 9      585858
# 10    1049400
# 11    2547363
# 12    3094650
# 13    1763916
# 14    1043130
# Name: budget, dtype: int64

# %%
budget_per_capita=school_data.iloc[:,4]/school_data.iloc[:,3]
budget_per_capita
# Out:
# 0     655.0
# 1     639.0
# 2     600.0
# 3     652.0
# 4     625.0
# 5     578.0
# 6     582.0
# 7     628.0
# 8     581.0
# 9     609.0
# 10    583.0
# 11    637.0
# 12    650.0
# 13    644.0
# 14    638.0
# dtype: float64

# %%
students_passing_math_and_reading = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)]
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()

students_passing_math_and_reading.value_counts()
# Out:
# Student ID  student_name       gender  grade  school_name          reading_score  math_score  School ID  type      size  budget
# 4           Bonnie Ray         F       9th    Huang High School    97             84          0          District  2917  1910635    1
# 25077       Timothy Marshall   M       9th    Wright High School   84             97          10         Charter   1800  1049400    1
# 25074       Michael Robinson   M       10th   Wright High School   75             77          10         Charter   1800  1049400    1
# 25073       Megan Ramsey       F       10th   Wright High School   74             98          10         Charter   1800  1049400    1
# 25072       Dalton Fisher      M       9th    Wright High School   98             96          10         Charter   1800  1049400    1
#                                                                                                                                    ..
# ...

# %%
Huang = school_data_complete.groupby[["school_name"]=="Huang High School"]
#Huang = school_data_complete.groupby("school_name").get_group("Huang High School")
P=Huang(["math_score"]>70).count.sum()
Print(Huang["reading_score"].mean())

# %%
passing_math=(school_data_complete["math_score"] >= 70).sum
passing_math()
# Out:
# 29370

# %%
passing_reading=(school_data_complete["reading_score"] >= 70).sum
passing_reading()
# Out:
# 33610

# %%
# Use the provided code to calculate the number of students per school that passed both math and reading with scores of 70 or higher
students_passing_math_and_reading = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)]
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()

students_passing_math_and_reading.value_counts()

# %%
Huang_hs_df = school_data_complete[school_data_complete["school_name"] == "Huang High School"]
Figueroa_hs_df = school_data_complete[school_data_complete["school_name"] == "Figueroa High School"]
Shelton_hs_df = school_data_complete[school_data_complete["school_name"] == "Shelton High School"]
Hernandez_hs_df = school_data_complete[school_data_complete["school_name"] == "Hernandez High School"]
Griffin_hs_df = school_data_complete[school_data_complete["school_name"] == "Griffin High School"]
Wilson_hs_df = school_data_complete[school_data_complete["school_name"] == "Wilson High School"]
Cabrera_hs_df = school_data_complete[school_data_complete["school_name"] == "Cabrera High School"]
Bailey_hs_df = school_data_complete[school_data_complete["school_name"] == "Bailey High School"]
Holden_hs_df = school_data_complete[school_data_complete["school_name"] == "Holden High School"]
Pena_hs_df = school_data_complete[school_data_complete["school_name"] == "Pena High School"]
Wright_hs_df = school_data_complete[school_data_complete["school_name"] == "Wright High School"]
Rodriguez_hs_df = school_data_complete[school_data_complete["school_name"] == "Rodriguez High School"]
Johnson_hs_df = school_data_complete[school_data_complete["school_name"] == "Johnson High School"]
Ford_hs_df = school_data_complete[school_data_complete["school_name"] == "Ford High School"]
Thomas_hs_df = school_data_complete[school_data_complete["school_name"] == "Thomas High School"]
